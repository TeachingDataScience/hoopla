# %% [markdown]
# # Table of Contents

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import cPickle as pickle
# %pylab inline
import seaborn as sns
import sys
import statsmodels.formula.api as smf

sys.path.append('./hoopla')


from hoopla import hoopla as hp

import charts
import mpld3
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Server running in the folder /cust/data-story/nba at 127.0.0.1:47828

# %% [markdown]
# # Using charts
#
# From [python-highcarts](http://nbviewer.ipython.org/github/arnoutaertgeerts/python-highcharts/blob/master/Tutorial.ipynb)

# %%
df=pd.read_pickle("data/fullstats_lac_gsw_20132016_11112015_185155.p")
topouts = pd.read_pickle("data/topouts_lac_gsw_11122015_232448.p")

# %%
v = "REB_PCT"
target = "PLUS_MINUS"

# %%
chart_df = df[[v,target]]

# %%
data = pd.DataFrame(chart_df.PLUS_MINUS.tolist(),chart_df.REB_PCT.tolist())
data = data.reset_index()
data.columns = ['Rebound Percentage','Plus Minus']
data = data.set_index('Plus Minus')

# %%
# Out:
# ',Rebound Percentage,Plus Minus\n0,0.556,10.0\n1,0.652,3.0\n2,0.474,0.0\n3,0.588,-2.0\n4,0.538,8.0\n5,0.318,-6.0\n6,0.474,1.0\n7,0.4,-5.0\n8,0.409,-11.0\n9,0.385,3.0\n10,0.231,-15.0\n11,0.538,4.0\n12,0.545,0.0\n13,0.524,-2.0\n14,0.6,7.0\n15,0.636,8.0\n16,0.364,-10.0\n17,0.417,-13.0\n18,0.333,-4.0\n19,0.565,10.0\n20,0.571,-2.0\n21,0.542,1.0\n22,0.467,4.0\n23,0.519,11.0\n24,0.684,-1.0\n25,0.318,-6.0\n26,0.588,-12.0\n27,0.5,11.0\n28,0.56,12.0\n29,0.522,-5.0\n30,0.368,-1.0\n31,0.471,-10.0\n32,0.478,-6.0\n33,0.421,-1.0\n34,0.579,8.0\n35,0.5,-5.0\n'

# %%
options = dict(height=400, title=dict(text='Clippers vs Warriors, Quarters'),yAxis=dict(title=dict(text="Point Differential")))
#options["xAxis"]=dict(title=dict(text="REB_PCT"))
#options["series"]=dict(name = "REB_PCT")
options['credits']=dict(enabled = 'false',text='')
charts.plot(data, options=options, name='fff', save='temp.html', type='scatter', show='inline')
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;font-family:sans-serif}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# ...

# %%
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;font-family:sans-serif}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# ...

# %% [markdown]
# # using mpld3

# %% [markdown]
# ### Stock Example

# %%
fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
N = 100

scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s=1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)
ax.grid(color='white', linestyle='solid')

ax.set_title("Scatter Plot (with tooltips!)", size=20)

labels = ['point {0}'.format(i + 1) for i in range(N)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el2305140371632891984813628903"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %% [markdown]
# ## NBA Example

# %%
labeldata = df.index.tolist()

# %%
data = data.reset_index()

# %%
data.head()
Y = data['Plus Minus']
X = data['Rebound Percentage']

# %%
mpld3.plugins.connect?

# %%
fig, ax = plt.subplots()
N = 100

thechart = ax.scatter(X,Y,alpha=0,color="r")

sns.regplot(X,Y)


ax.set_title("NBA Rebound Impact by Quarter (Hover for Quarter)", size=15)

labels = labeldata
tooltip = mpld3.plugins.PointLabelTooltip(thechart, labels=labels)
#mpld3.plugins.clear(fig)

mpld3.plugins.connect(fig, tooltip)

#mpld3.save_html("outputs/scatter_tools.html")
mpld3.enable_notebook()
mpld3.save_html(fig,"figure.html")
