# %% [markdown]
# # Table of Contents
# * [Libraries](#Libraries)
# * [Example Requests](#Example-Requests)
# 	* &nbsp;
# 		* [Header Diagnosis](#Header-Diagnosis)
# * [Accessing Play by Play Data via API](#Accessing-Play-by-Play-Data-via-API)
# * [Quarterly Game Data by Team](#Quarterly-Game-Data-by-Team)
# 	* [With no iterations](#With-no-iterations)
# 		* [Grab desired arguments](#Grab-desired-arguments)
# 		* [Load Arguments](#Load-Arguments)
# 		* [Grab data](#Grab-data)
# 	* [Prep for Quarterly Data with Iterations](#Prep-for-Quarterly-Data-with-Iterations)
# * [Data Acquisition Script](#Data-Acquisition-Script)
# * [Functions and Constants](#Functions-and-Constants)

# %% [markdown]
# # Libraries

# %%
import requests
import pandas as pd
import numpy as np

import cPickle as pickle

import urllib2


# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Example Requests

# %% [markdown]
# * Load the page
# * Check network, XHR filters
# * Grab the relevant request url
#
# For example: This [initial link](http://stats.nba.com/league/player/#!/advanced/?sort=PIE&dir=1&Season=2014-15&SeasonType=Pre%20Season) leads to [target link](http://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=Totals&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season=2014-15&SeasonSegment=&SeasonType=Pre+Season&ShotClockRange=&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=)

# %%
# Example

url="http://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=Totals&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season=2014-15&SeasonSegment=&SeasonType=Pre+Season&ShotClockRange=&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight="

response=requests.get(url)
response.raise_for_status()
#data = response.json()['resultSets'][0]['rowSet']

# %% [markdown]
# ### Header Diagnosis

# %%
# Checkout keys to find appropriate key
response.json().keys()
# Out:
# [u'resource', u'resultSets', u'parameters']

# %%
# Convert headers and stats to frame

# %%
    
    
# View the headers
headers = response.json()['resultSets'][0]['headers']

# Looks like a list of 512 stats
stats = response.json()['resultSets'][0]['rowSet']

df = pd.DataFrame(stats,columns = headers )

df.head()
# Out:
#    PLAYER_ID    PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  AGE  GP  W  L  \
# 0     201985     A.J. Price  1610612756               PHX   28   6  4  2
# 1     201166   Aaron Brooks  1610612741               CHI   30   8  4  4
# 2     203905    Aaron Craft  1610612744               GSW   24   4  2  2
# 3     203932   Aaron Gordon  1610612753               ORL   19   8  4  4
# 4     203519  Adonis Thomas  1610612754               IND   22   4  2  2
#
#    W_PCT   MIN        ...          USG_PCT    PACE    PIE  FGM  FGA  FGM_PG  \
# 0  0.667  13.3        ...            0.217   95.68  0.106   15   33     2.5
# 1  0.500  19.5        ...            0.230   94.30  0.072   22   59     2.8
# 2  0.500  14.7        ...            0.130   98.15  0.081    5   10     1.3
# 3  0.500  22.2        ...            0.183  100.18  0.097   26   56     3.3
# 4  0.500   8.9        ...            0.142   94.97  0.025    2   10     0.5
#
#    FGA_PG  FG_PCT  CFID           CFPARAMS
# 0     5.5   0.455     5  201985,1610612756
# 1     7.4   0.373     5  201166,1610612741
# 2     2.5   0.500     5  203905,1610612744
# 3     7.0   0.464     5  203932,1610612753
# 4     2.5   0.200     5  203519,1610612754
#
# [5 rows x 32 columns]

# %% [markdown]
# # Accessing Play by Play Data via API

# %% [markdown]
# Example URL:
#
# `http://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021500020&RangeType=2&Season=2015-16&SeasonType=Regular+Season&StartPeriod=1&StartRange=0`

# %%
playurl = "http://stats.nba.com/stats/playbyplayv2?EndPeriod=10&EndRange=55800&GameID=0021500020&RangeType=2&Season=2015-16&SeasonType=Regular+Season&StartPeriod=1&StartRange=0"

# %%
response=requests.get(playurl)
response.raise_for_status()

# %%
df = response_to_frame(response)

# %%
df.head(2)
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0  0021500020         0            12                   0       1
# 1  0021500020         1            10                   0       1
#
#   WCTIMESTRING PCTIMESTRING                                HOMEDESCRIPTION  \
# 0     10:51 PM        12:00                                           None
# 1     10:51 PM        12:00  Jump Ball Jordan vs. Pachulia: Tip to Griffin
#
#   NEUTRALDESCRIPTION VISITORDESCRIPTION            ...              \
# 0               None               None            ...
# 1               None               None            ...
#
#   PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  PLAYER2_TEAM_ABBREVIATION  \
# 0              None                  None                       None
# 1            Dallas             Mavericks                        DAL
#
#    PERSON3TYPE PLAYER3_ID   PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 0            0          0           None             NaN              None
# 1            4     201933  Blake Griffin      1610612746       Los Angeles
#
#   PLAYER3_TEAM_NICKNAME  PLAYER3_TEAM_ABBREVIATION
# 0                  None                       None
# 1              Clippers                        LAC
#
# [2 rows x 33 columns]

# %% [markdown]
# ## Data on Per-Play Basis Excludes TO and Rebounds as Plays

# %%
# Determine number of plays
# Wondering if 4th quarter LAC plays = 28
print "Total Plays"
for P in [1,2,3,4]:
    print "Plays in Period %s = %s" % (str(P),str(len(df[df.PERIOD ==P])))
# Out:
# Total Plays
# Plays in Period 1 = 134
# Plays in Period 2 = 136
# Plays in Period 3 = 124
# Plays in Period 4 = 108

# %%
print "LAC Plays"
for P in [1,2,3,4]:
    print "Plays in Period %s = %s" % (str(P),str(len(df[~df.HOMEDESCRIPTION.isnull()][df.PERIOD ==P])))
# Out:
# LAC Plays
# Plays in Period 1 = 74
# Plays in Period 2 = 69
# Plays in Period 3 = 56
# Plays in Period 4 = 57
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.py:1819: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
fourth = df[~df.HOMEDESCRIPTION.isnull()][df.PERIOD ==4]

# %%
fourth
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 395  0021500020       454             2                  45       4
# 397  0021500020       456             2                  42       4
# 398  0021500020       457             4                   0       4
# 399  0021500020       458             1                  98       4
# 400  0021500020       459             6                   1       4
# 402  0021500020       461             6                   2       4
# 404  0021500020       464             1                   1       4
# 406  0021500020       466             4                   0       4
# 407  0021500020       467             1                  43       4
# 409  0021500020       469             4                   0       4
# 411  0021500020       471             3                  11       4
# 412  0021500020       472             4                   1       4
# 415  0021500020       476             3                  12       4
# 418  0021500020       480             4                   0       4
# 419  0021500020       481             2                   3       4
# 420  0021500020       482             4                   0       4
# 421  0021500020       483             2                  97       4
# 422  0021500020       484             4                   0       4
# 423  0021500020       485             1                  97       4
# 426  0021500020       489             4                   0       4
# 427  0021500020       490             2                   1       4
# 431  0021500020       494             2                   1       4
# 433  0021500020       496             2                   1       4
# 434  0021500020       497             4                   0       4
# 435  0021500020       498             1                  79       4
# 437  0021500020       500             2                   1       4
# 439  0021500020       502             5                   1       4
# 441  0021500020       504             3                  11       4
# 442  0021500020       506             8                   0       4
# 443  0021500020       507             3                  12       4
# 445  0021500020       510             4                   0       4
# 446  0021500020       511             8                   0       4
# 447  0021500020       512             8                   0       4
# 448  0021500020       513             1                   1       4
# 450  0021500020       515             4                   0       4
# 451  0021500020       516             1                  98       4
# 453  0021500020       518             2                   1       4
# 456  0021500020       521             4                   0       4
# 457  0021500020       522             2                   3       4
# 462  0021500020       528             4                   0       4
# 463  0021500020       529             5                   1       4
# 465  0021500020       531             2                   1       4
# 466  0021500020       532             4                   0       4
# 467  0021500020       533             2                   1       4
# 472  0021500020       538             4                   0       4
# 473  0021500020       539             5                   1       4
# 475  0021500020       541             2                   1       4
# 478  0021500020       544             4                   0       4
# 479  0021500020       545             2                   5       4
# 482  0021500020       548             4                   0       4
# 483  0021500020       549             2                   1       4
# 486  0021500020       552             2                   1       4
# 488  0021500020       554             6                   2       4
# 492  0021500020       562             2                   1       4
# 495  0021500020       565             4                   0       4
# 496  0021500020       566             2                   1       4
# 499  0021500020       569             1                   1       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 395     12:50 AM        11:45
# 397     12:51 AM        11:24
# 398     12:51 AM        11:22
# 399     12:51 AM        11:00
# 400     12:51 AM        10:55
# 402     12:52 AM        10:43
# 404     12:52 AM        10:30
# 406     12:53 AM        10:14
# 407     12:53 AM        10:08
# 409     12:53 AM         9:47
# 411     12:53 AM         9:39
# 412     12:53 AM         9:39
# 415     12:54 AM         9:39
# 418     12:54 AM         9:26
# 419     12:55 AM         9:12
# 420     12:55 AM         9:12
# 421     12:55 AM         9:12
# 422     12:55 AM         9:12
# 423     12:55 AM         9:12
# 426     12:58 AM         8:55
# 427     12:58 AM         8:44
# 431     12:59 AM         8:17
# 433     12:59 AM         8:05
# 434     12:59 AM         8:03
# 435     12:59 AM         7:54
# 437      1:00 AM         7:17
# 439      1:00 AM         7:08
# 441      1:00 AM         7:05
# 442      1:01 AM         7:05
# 443      1:01 AM         7:05
# 445      1:01 AM         6:54
# 446      1:01 AM         6:54
# 447      1:01 AM         6:54
# 448      1:01 AM         6:44
# 450      1:02 AM         6:28
# 451      1:02 AM         6:18
# 453      1:02 AM         5:42
# 456      1:03 AM         5:29
# 457      1:03 AM         5:11
# 462      1:06 AM         4:47
# 463      1:07 AM         4:32
# 465      1:07 AM         4:09
# 466      1:07 AM         4:08
# 467      1:07 AM         4:04
# 472      1:08 AM         3:38
# 473      1:08 AM         3:24
# 475      1:08 AM         3:01
# 478      1:08 AM         2:56
# 479      1:08 AM         2:46
# 482      1:09 AM         2:30
# 483      1:09 AM         2:20
# 486      1:09 AM         1:53
# 488      1:10 AM         1:35
# 492      1:13 AM         1:21
# 495      1:14 AM         0:58
# 496      1:14 AM         0:42
# 499      1:15 AM         0:11
#
#                                        HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 395                      MISS Pierce 25' 3PT Jump Shot               None
# 397                           W. Johnson BLOCK (1 BLK)               None
# 398                        Smith REBOUND (Off:1 Def:2)               None
# 399  Rivers 2' Cutting Layup Shot (9 PTS) (Pierce 2...               None
# 400                    Smith P.FOUL (P4.T1) (S.Corbin)               None
# 402                    Pierce S.FOUL (P2.T2) (E.Dalen)               None
# 404  Rivers 26' 3PT Jump Shot (12 PTS) (Crawford 1 ...               None
# 406                       Pierce REBOUND (Off:0 Def:3)               None
# 407  W. Johnson 4' Alley Oop Layup (4 PTS) (Crawfor...               None
# 409                        Smith REBOUND (Off:1 Def:3)               None
# 411                       MISS Smith Free Throw 1 of 2               None
# 412                                   CLIPPERS Rebound               None
# 415                       MISS Smith Free Throw 2 of 2               None
# 418                       Pierce REBOUND (Off:0 Def:4)               None
# 419                            MISS Smith 5' Hook Shot               None
# 420                        Smith REBOUND (Off:2 Def:3)               None
# 421                       MISS Smith 4' Tip Layup Shot               None
# 422                        Smith REBOUND (Off:3 Def:3)               None
# 423                    Smith 1' Tip Layup Shot (5 PTS)               None
# 426                   W. Johnson REBOUND (Off:0 Def:2)               None
# 427                        MISS Crawford 11' Jump Shot               None
# 431                      MISS Rivers 25' 3PT Jump Shot               None
# 433                                Smith BLOCK (2 BLK)               None
# 434                     Crawford REBOUND (Off:0 Def:2)               None
# 435             Crawford 18' Pullup Jump Shot (15 PTS)               None
# 437                  MISS W. Johnson 24' 3PT Jump Shot               None
# 439                               Pierce STEAL (2 STL)               None
# 441                   Pierce Free Throw 1 of 2 (5 PTS)               None
# 442                         SUB: Prigioni FOR Crawford               None
# 443                   Pierce Free Throw 2 of 2 (6 PTS)               None
# 445                                   CLIPPERS Rebound               None
# 446                       SUB: Mbah a Moute FOR Pierce               None
# 447                             SUB: Aldrich FOR Smith               None
# 448  W. Johnson 16' Jump Shot (6 PTS) (Mbah a Moute...               None
# 450                     Prigioni REBOUND (Off:0 Def:1)               None
# 451  Aldrich 2' Cutting Layup Shot (2 PTS) (Prigion...               None
# 453                         MISS Prigioni 1' Jump Shot               None
# 456                   W. Johnson REBOUND (Off:0 Def:3)               None
# 457                          MISS Aldrich 7' Hook Shot               None
# 462                   W. Johnson REBOUND (Off:0 Def:4)               None
# 463                  Aldrich Bad Pass Turnover (P1.T7)               None
# 465                    MISS Prigioni 26' 3PT Jump Shot               None
# 466                   W. Johnson REBOUND (Off:1 Def:4)               None
# 467                      MISS Rivers 26' 3PT Jump Shot               None
# 472                       Rivers REBOUND (Off:0 Def:1)               None
# 473                 Prigioni Bad Pass Turnover (P1.T8)               None
# 475                    MISS Prigioni 27' 3PT Jump Shot               None
# 478                       Rivers REBOUND (Off:0 Def:2)               None
# 479                               MISS Rivers 3' Layup               None
# 482                   W. Johnson REBOUND (Off:1 Def:5)               None
# 483                    MISS Prigioni 27' 3PT Jump Shot               None
# 486                  MISS W. Johnson 25' 3PT Jump Shot               None
# 488                  Aldrich S.FOUL (P1.T3) (J.Capers)               None
# 492                  MISS W. Johnson 24' 3PT Jump Shot               None
# 495                   W. Johnson REBOUND (Off:1 Def:6)               None
# 496                    MISS Mbah a Moute 14' Jump Shot               None
# 499                      Rivers 21' Jump Shot (14 PTS)               None
#
#                       VISITORDESCRIPTION            ...              \
# 395                                 None            ...
# 397       MISS Nowitzki 4' Driving Layup            ...
# 398                                 None            ...
# 399                                 None            ...
# 400                                 None            ...
# 402                                 None            ...
# 404                                 None            ...
# 406                                 None            ...
# 407                                 None            ...
# 409                                 None            ...
# 411                                 None            ...
# 412                                 None            ...
# 415                                 None            ...
# 418                                 None            ...
# 419                                 None            ...
# 420                                 None            ...
# 421                                 None            ...
# 422                                 None            ...
# 423                                 None            ...
# 426                                 None            ...
# 427                                 None            ...
# 431                                 None            ...
# 433           MISS Anderson 4' Jump Shot            ...
# 434                                 None            ...
# 435                                 None            ...
# 437                                 None            ...
# 439  Anderson Bad Pass Turnover (P2.T13)            ...
# 441                                 None            ...
# 442                                 None            ...
# 443                                 None            ...
# 445                                 None            ...
# 446                                 None            ...
# 447                                 None            ...
# 448                                 None            ...
# 450                                 None            ...
# 451                                 None            ...
# 453               Anderson BLOCK (1 BLK)            ...
# 456                                 None            ...
# 457                                 None            ...
# 462                                 None            ...
# 463               Anderson STEAL (1 STL)            ...
# 465                                 None            ...
# 466                                 None            ...
# 467                                 None            ...
# 472                                 None            ...
# 473                  Mejri STEAL (1 STL)            ...
# 475                                 None            ...
# 478                                 None            ...
# 479                  Mejri BLOCK (1 BLK)            ...
# 482                                 None            ...
# 483                                 None            ...
# 486                                 None            ...
# 488                                 None            ...
# 492                                 None            ...
# 495                                 None            ...
# 496                                 None            ...
# 499                                 None            ...
#
#     PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  PLAYER2_TEAM_ABBREVIATION  \
# 395              None                  None                       None
# 397              None                  None                       None
# 398              None                  None                       None
# 399       Los Angeles              Clippers                        LAC
# 400            Dallas             Mavericks                        DAL
# 402            Dallas             Mavericks                        DAL
# 404       Los Angeles              Clippers                        LAC
# 406              None                  None                       None
# 407       Los Angeles              Clippers                        LAC
# 409              None                  None                       None
# 411              None                  None                       None
# 412              None                  None                       None
# 415              None                  None                       None
# 418              None                  None                       None
# 419              None                  None                       None
# 420              None                  None                       None
# 421              None                  None                       None
# 422              None                  None                       None
# 423              None                  None                       None
# 426              None                  None                       None
# 427              None                  None                       None
# 431              None                  None                       None
# 433              None                  None                       None
# 434              None                  None                       None
# 435              None                  None                       None
# 437              None                  None                       None
# 439       Los Angeles              Clippers                        LAC
# 441              None                  None                       None
# 442       Los Angeles              Clippers                        LAC
# 443              None                  None                       None
# 445              None                  None                       None
# 446       Los Angeles              Clippers                        LAC
# 447       Los Angeles              Clippers                        LAC
# 448       Los Angeles              Clippers                        LAC
# 450              None                  None                       None
# 451       Los Angeles              Clippers                        LAC
# 453              None                  None                       None
# 456              None                  None                       None
# 457              None                  None                       None
# 462              None                  None                       None
# 463            Dallas             Mavericks                        DAL
# 465              None                  None                       None
# 466              None                  None                       None
# 467              None                  None                       None
# 472              None                  None                       None
# 473            Dallas             Mavericks                        DAL
# 475              None                  None                       None
# 478              None                  None                       None
# 479              None                  None                       None
# 482              None                  None                       None
# 483              None                  None                       None
# 486              None                  None                       None
# 488            Dallas             Mavericks                        DAL
# 492              None                  None                       None
# 495              None                  None                       None
# 496              None                  None                       None
# 499              None                  None                       None
#
#      PERSON3TYPE PLAYER3_ID     PLAYER3_NAME PLAYER3_TEAM_ID  \
# 395            0          0             None             NaN
# 397            4     202325   Wesley Johnson      1610612746
# 398            0          0             None             NaN
# 399            0          0             None             NaN
# 400            1          0             None             NaN
# 402            1          0             None             NaN
# 404            0          0             None             NaN
# 406            0          0             None             NaN
# 407            0          0             None             NaN
# 409            0          0             None             NaN
# 411            0          0             None             NaN
# 412            0          0             None             NaN
# 415            0          0             None             NaN
# 418            0          0             None             NaN
# 419            0          0             None             NaN
# 420            0          0             None             NaN
# 421            0          0             None             NaN
# 422            0          0             None             NaN
# 423            0          0             None             NaN
# 426            0          0             None             NaN
# 427            0          0             None             NaN
# 431            0          0             None             NaN
# 433            4       2746       Josh Smith      1610612746
# 434            0          0             None             NaN
# 435            0          0             None             NaN
# 437            0          0             None             NaN
# 439            0          0             None             NaN
# 441            0          0             None             NaN
# 442            0          0             None             NaN
# 443            0          0             None             NaN
# 445            0          0             None             NaN
# 446            0          0             None             NaN
# 447            0          0             None             NaN
# 448            0          0             None             NaN
# 450            0          0             None             NaN
# 451            0          0             None             NaN
# 453            5    1626147  Justin Anderson      1610612742
# 456            0          0             None             NaN
# 457            0          0             None             NaN
# 462            0          0             None             NaN
# 463            0          0             None             NaN
# 465            0          0             None             NaN
# 466            0          0             None             NaN
# 467            0          0             None             NaN
# 472            0          0             None             NaN
# 473            0          0             None             NaN
# 475            0          0             None             NaN
# 478            0          0             None             NaN
# 479            5    1626257      Salah Mejri      1610612742
# 482            0          0             None             NaN
# 483            0          0             None             NaN
# 486            0          0             None             NaN
# 488            1          0             None             NaN
# 492            0          0             None             NaN
# 495            0          0             None             NaN
# 496            0          0             None             NaN
# 499            0          0             None             NaN
#
#     PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  PLAYER3_TEAM_ABBREVIATION
# 395              None                  None                       None
# 397       Los Angeles              Clippers                        LAC
# 398              None                  None                       None
# 399              None                  None                       None
# 400              None                  None                       None
# 402              None                  None                       None
# 404              None                  None                       None
# 406              None                  None                       None
# 407              None                  None                       None
# 409              None                  None                       None
# 411              None                  None                       None
# 412              None                  None                       None
# 415              None                  None                       None
# 418              None                  None                       None
# 419              None                  None                       None
# 420              None                  None                       None
# 421              None                  None                       None
# 422              None                  None                       None
# 423              None                  None                       None
# 426              None                  None                       None
# 427              None                  None                       None
# 431              None                  None                       None
# 433       Los Angeles              Clippers                        LAC
# 434              None                  None                       None
# 435              None                  None                       None
# 437              None                  None                       None
# 439              None                  None                       None
# 441              None                  None                       None
# 442              None                  None                       None
# 443              None                  None                       None
# 445              None                  None                       None
# 446              None                  None                       None
# 447              None                  None                       None
# 448              None                  None                       None
# 450              None                  None                       None
# 451              None                  None                       None
# 453            Dallas             Mavericks                        DAL
# 456              None                  None                       None
# 457              None                  None                       None
# 462              None                  None                       None
# 463              None                  None                       None
# 465              None                  None                       None
# 466              None                  None                       None
# 467              None                  None                       None
# 472              None                  None                       None
# 473              None                  None                       None
# 475              None                  None                       None
# 478              None                  None                       None
# 479            Dallas             Mavericks                        DAL
# 482              None                  None                       None
# 483              None                  None                       None
# 486              None                  None                       None
# 488              None                  None                       None
# 492              None                  None                       None
# 495              None                  None                       None
# 496              None                  None                       None
# 499              None                  None                       None
#
# [57 rows x 33 columns]

# %%
print "Number of 4th quarter...\nfouls: %s" % fourth.HOMEDESCRIPTION.str.contains("FOUL").sum()
print "Free throws: %s" % fourth.HOMEDESCRIPTION.str.contains("Free").sum()
print "Rebounds: %s" % fourth.HOMEDESCRIPTION.str.contains("Rebound").sum()
# Out:
# Number of 4th quarter...
# fouls: 3
# Free throws: 4
# Rebounds: 2

# %%
# Maybe exclude when EVENTMSGACTIONTYPE is 0 (rebound) or 1 (TO)
fourth[(fourth["EVENTMSGACTIONTYPE"] != 0) & (fourth["EVENTMSGACTIONTYPE"] != 1) ]
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 395  0021500020       454             2                  45       4
# 397  0021500020       456             2                  42       4
# 399  0021500020       458             1                  98       4
# 402  0021500020       461             6                   2       4
# 407  0021500020       467             1                  43       4
# 411  0021500020       471             3                  11       4
# 415  0021500020       476             3                  12       4
# 419  0021500020       481             2                   3       4
# 421  0021500020       483             2                  97       4
# 423  0021500020       485             1                  97       4
# 435  0021500020       498             1                  79       4
# 441  0021500020       504             3                  11       4
# 443  0021500020       507             3                  12       4
# 451  0021500020       516             1                  98       4
# 457  0021500020       522             2                   3       4
# 479  0021500020       545             2                   5       4
# 488  0021500020       554             6                   2       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 395     12:50 AM        11:45
# 397     12:51 AM        11:24
# 399     12:51 AM        11:00
# 402     12:52 AM        10:43
# 407     12:53 AM        10:08
# 411     12:53 AM         9:39
# 415     12:54 AM         9:39
# 419     12:55 AM         9:12
# 421     12:55 AM         9:12
# 423     12:55 AM         9:12
# 435     12:59 AM         7:54
# 441      1:00 AM         7:05
# 443      1:01 AM         7:05
# 451      1:02 AM         6:18
# 457      1:03 AM         5:11
# 479      1:08 AM         2:46
# 488      1:10 AM         1:35
#
#                                        HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 395                      MISS Pierce 25' 3PT Jump Shot               None
# 397                           W. Johnson BLOCK (1 BLK)               None
# 399  Rivers 2' Cutting Layup Shot (9 PTS) (Pierce 2...               None
# 402                    Pierce S.FOUL (P2.T2) (E.Dalen)               None
# 407  W. Johnson 4' Alley Oop Layup (4 PTS) (Crawfor...               None
# 411                       MISS Smith Free Throw 1 of 2               None
# 415                       MISS Smith Free Throw 2 of 2               None
# 419                            MISS Smith 5' Hook Shot               None
# 421                       MISS Smith 4' Tip Layup Shot               None
# 423                    Smith 1' Tip Layup Shot (5 PTS)               None
# 435             Crawford 18' Pullup Jump Shot (15 PTS)               None
# 441                   Pierce Free Throw 1 of 2 (5 PTS)               None
# 443                   Pierce Free Throw 2 of 2 (6 PTS)               None
# 451  Aldrich 2' Cutting Layup Shot (2 PTS) (Prigion...               None
# 457                          MISS Aldrich 7' Hook Shot               None
# 479                               MISS Rivers 3' Layup               None
# 488                  Aldrich S.FOUL (P1.T3) (J.Capers)               None
#
#                  VISITORDESCRIPTION            ...              \
# 395                            None            ...
# 397  MISS Nowitzki 4' Driving Layup            ...
# 399                            None            ...
# 402                            None            ...
# 407                            None            ...
# 411                            None            ...
# 415                            None            ...
# 419                            None            ...
# 421                            None            ...
# 423                            None            ...
# 435                            None            ...
# 441                            None            ...
# 443                            None            ...
# 451                            None            ...
# 457                            None            ...
# 479             Mejri BLOCK (1 BLK)            ...
# 488                            None            ...
#
#     PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  PLAYER2_TEAM_ABBREVIATION  \
# 395              None                  None                       None
# 397              None                  None                       None
# 399       Los Angeles              Clippers                        LAC
# 402            Dallas             Mavericks                        DAL
# 407       Los Angeles              Clippers                        LAC
# 411              None                  None                       None
# 415              None                  None                       None
# 419              None                  None                       None
# 421              None                  None                       None
# 423              None                  None                       None
# 435              None                  None                       None
# 441              None                  None                       None
# 443              None                  None                       None
# 451       Los Angeles              Clippers                        LAC
# 457              None                  None                       None
# 479              None                  None                       None
# 488            Dallas             Mavericks                        DAL
#
#      PERSON3TYPE PLAYER3_ID    PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 395            0          0            None             NaN              None
# 397            4     202325  Wesley Johnson      1610612746       Los Angeles
# 399            0          0            None             NaN              None
# 402            1          0            None             NaN              None
# 407            0          0            None             NaN              None
# 411            0          0            None             NaN              None
# 415            0          0            None             NaN              None
# 419            0          0            None             NaN              None
# 421            0          0            None             NaN              None
# 423            0          0            None             NaN              None
# 435            0          0            None             NaN              None
# 441            0          0            None             NaN              None
# 443            0          0            None             NaN              None
# 451            0          0            None             NaN              None
# 457            0          0            None             NaN              None
# 479            5    1626257     Salah Mejri      1610612742            Dallas
# 488            1          0            None             NaN              None
#
#     PLAYER3_TEAM_NICKNAME  PLAYER3_TEAM_ABBREVIATION
# 395                  None                       None
# 397              Clippers                        LAC
# 399                  None                       None
# 402                  None                       None
# 407                  None                       None
# 411                  None                       None
# 415                  None                       None
# 419                  None                       None
# 421                  None                       None
# 423                  None                       None
# 435                  None                       None
# 441                  None                       None
# 443                  None                       None
# 451                  None                       None
# 457                  None                       None
# 479             Mavericks                        DAL
# 488                  None                       None
#
# [17 rows x 33 columns]

# %%
fourth[(fourth["EVENTMSGACTIONTYPE"] != 0) & (fourth["EVENTMSGACTIONTYPE"] != 1) ]
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 395  0021500020       454             2                  45       4
# 397  0021500020       456             2                  42       4
# 399  0021500020       458             1                  98       4
# 402  0021500020       461             6                   2       4
# 407  0021500020       467             1                  43       4
# 411  0021500020       471             3                  11       4
# 415  0021500020       476             3                  12       4
# 419  0021500020       481             2                   3       4
# 421  0021500020       483             2                  97       4
# 423  0021500020       485             1                  97       4
# 435  0021500020       498             1                  79       4
# 441  0021500020       504             3                  11       4
# 443  0021500020       507             3                  12       4
# 451  0021500020       516             1                  98       4
# 457  0021500020       522             2                   3       4
# 479  0021500020       545             2                   5       4
# 488  0021500020       554             6                   2       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 395     12:50 AM        11:45
# 397     12:51 AM        11:24
# 399     12:51 AM        11:00
# 402     12:52 AM        10:43
# 407     12:53 AM        10:08
# 411     12:53 AM         9:39
# 415     12:54 AM         9:39
# 419     12:55 AM         9:12
# 421     12:55 AM         9:12
# 423     12:55 AM         9:12
# 435     12:59 AM         7:54
# 441      1:00 AM         7:05
# 443      1:01 AM         7:05
# 451      1:02 AM         6:18
# 457      1:03 AM         5:11
# 479      1:08 AM         2:46
# 488      1:10 AM         1:35
#
#                                        HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 395                      MISS Pierce 25' 3PT Jump Shot               None
# 397                           W. Johnson BLOCK (1 BLK)               None
# 399  Rivers 2' Cutting Layup Shot (9 PTS) (Pierce 2...               None
# 402                    Pierce S.FOUL (P2.T2) (E.Dalen)               None
# 407  W. Johnson 4' Alley Oop Layup (4 PTS) (Crawfor...               None
# 411                       MISS Smith Free Throw 1 of 2               None
# 415                       MISS Smith Free Throw 2 of 2               None
# 419                            MISS Smith 5' Hook Shot               None
# 421                       MISS Smith 4' Tip Layup Shot               None
# 423                    Smith 1' Tip Layup Shot (5 PTS)               None
# 435             Crawford 18' Pullup Jump Shot (15 PTS)               None
# 441                   Pierce Free Throw 1 of 2 (5 PTS)               None
# 443                   Pierce Free Throw 2 of 2 (6 PTS)               None
# 451  Aldrich 2' Cutting Layup Shot (2 PTS) (Prigion...               None
# 457                          MISS Aldrich 7' Hook Shot               None
# 479                               MISS Rivers 3' Layup               None
# 488                  Aldrich S.FOUL (P1.T3) (J.Capers)               None
#
#                  VISITORDESCRIPTION            ...              \
# 395                            None            ...
# 397  MISS Nowitzki 4' Driving Layup            ...
# 399                            None            ...
# 402                            None            ...
# 407                            None            ...
# 411                            None            ...
# 415                            None            ...
# 419                            None            ...
# 421                            None            ...
# 423                            None            ...
# 435                            None            ...
# 441                            None            ...
# 443                            None            ...
# 451                            None            ...
# 457                            None            ...
# 479             Mejri BLOCK (1 BLK)            ...
# 488                            None            ...
#
#     PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  PLAYER2_TEAM_ABBREVIATION  \
# 395              None                  None                       None
# 397              None                  None                       None
# 399       Los Angeles              Clippers                        LAC
# 402            Dallas             Mavericks                        DAL
# 407       Los Angeles              Clippers                        LAC
# 411              None                  None                       None
# 415              None                  None                       None
# 419              None                  None                       None
# 421              None                  None                       None
# 423              None                  None                       None
# 435              None                  None                       None
# 441              None                  None                       None
# 443              None                  None                       None
# 451       Los Angeles              Clippers                        LAC
# 457              None                  None                       None
# 479              None                  None                       None
# 488            Dallas             Mavericks                        DAL
#
#      PERSON3TYPE PLAYER3_ID    PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 395            0          0            None             NaN              None
# 397            4     202325  Wesley Johnson      1610612746       Los Angeles
# 399            0          0            None             NaN              None
# 402            1          0            None             NaN              None
# 407            0          0            None             NaN              None
# 411            0          0            None             NaN              None
# 415            0          0            None             NaN              None
# 419            0          0            None             NaN              None
# 421            0          0            None             NaN              None
# 423            0          0            None             NaN              None
# 435            0          0            None             NaN              None
# 441            0          0            None             NaN              None
# 443            0          0            None             NaN              None
# 451            0          0            None             NaN              None
# 457            0          0            None             NaN              None
# 479            5    1626257     Salah Mejri      1610612742            Dallas
# 488            1          0            None             NaN              None
#
#     PLAYER3_TEAM_NICKNAME  PLAYER3_TEAM_ABBREVIATION
# 395                  None                       None
# 397              Clippers                        LAC
# 399                  None                       None
# 402                  None                       None
# 407                  None                       None
# 411                  None                       None
# 415                  None                       None
# 419                  None                       None
# 421                  None                       None
# 423                  None                       None
# 435                  None                       None
# 441                  None                       None
# 443                  None                       None
# 451                  None                       None
# 457                  None                       None
# 479             Mavericks                        DAL
# 488                  None                       None
#
# [17 rows x 33 columns]

# %% [markdown]
# #  Quarterly Game Data by Team

# %% [markdown]
# ## With no iterations

# %% [markdown]
# ### Grab desired arguments

# %%
# Get gamedates as list
gamedates = get2014gamedates("Clippers","Warriors")

# %% [markdown]
# ### Load Arguments

# %%
#  Initialize payload
payload = init_payload()

# %%
newargs = {
    'DateFrom':gamedate,
    'DateTo':gamedate,
    'MeasureType':'Base',
    'Period':'1',
    'TeamID':'1610612746',
    'OpponentTeamID':'1610612744'
    
}

# %% [markdown]
# ### Grab data

# %% [markdown]
# ## Prep for Quarterly Data with Iterations

# %%
# Set additional iterations needed
Periods = ["1","2","3","4"]
MeasureTypes = ["Base","Advanced","Misc","Four Factors","Scoring","Opponent"] # "Usage" doesn't apply as these are team stats

# %%
# Create a master dictionary to hold each measure's data
superdatadict = dict()
for m in MeasureTypes:
    superdatadict[m] = 0

# %%
#  Save Super columns for Later Work
# supercolumns = periodframe.columns.tolist()
# pickle.dump(supercolumns,open("supercolumns.p","wb"))

# %% [markdown]
# # Data Acquisition Script

# %%
# Initialize list
quarters_list = []

for D in gamedates:
        newargs.update({'DateFrom':D,'DateTo':D})
        for P in Periods:
            newargs.update({"Period":P})
            # initialize a periodframe
            periodframe = pd.DataFrame()
            for m in MeasureTypes:
                print m

                newargs.update({"MeasureType":m}) # Set MeasureType
                newline = grabdataline(payload,newargs)
                # Check for new arguments
                old_cols = periodframe.columns.tolist()
                print old_cols
                all_new_cols = newline.columns.tolist()
                newcols = list(set(all_new_cols)-set(old_cols))     
                print newcols
                if old_cols == []: # If first measure type, initialize
                    print "initializing periodframe"
                    periodframe = newline
                else:

                    # Add columns to frame
                    periodframe = periodframe.join(newline[newcols])
            
            quarters_list.append(periodframe)
            
full_frame = pd.concat(quarters_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-ddd9ab46908c> in <module>()
#       2 quarters_list = []
#       3
# ----> 4 for D in gamedates:
#       5         newargs.update({'DateFrom':D,'DateTo':D})
#       6         for P in Periods:
#
# NameError: name 'gamedates' is not defined

# %%
# Save full data
# full_frame.to_pickle("data/fullstats_lac_gsw_20142015_103015_v1.p")

# %% [markdown]
# # Functions and Constants

# %%
# API Call List
apivariables = ["DateFrom","DateTo","Division","GameScope","GameSegment","LastNGames","LeagueID","Location","MeasureType","Month","OpponentTeamID","Outcome","PORound","PaceAdjust","PerMode","Period","PlayerExperience","PlayerPosition","PlusMinus","Rank","Season","SeasonSegment","SeasonType","ShotClockRange","StarterBench","TeamID","VsConference","VsDivision"]

# %%
# API Initialize List
dictinit={"LastNGames":"0","LeagueID":"00","MeasureType":"Base","Month":"0","TeamID":"0","OpponentTeamID":"0","PaceAdjust":"N","PaceAdjust":"N","Period":"0","PerMode":"Totals","PlusMinus":"N","PORound":"0","Rank":"N","Season":"2014-15","SeasonType":"Regular Season"}

# %%
def init_payload():
    """Initialize payload
    
    >>> payload = init_payload()
    """
    # Initialize payload
    _payload = {}

    # Load blank payload
    _payload = _payload.fromkeys(apivariables,"")

    # Load initialized values from payloadinit
    for k,v in dictinit.iteritems():
        _payload[k] = v
    return(_payload)

# %%
def get2014gamedates(team1,team2):
    """Get gamedates in a list for two teams
    """
    # Load df
    df = pd.read_csv("data/schedule_20142015_regularseason.csv")

    # Set Date
    df['Date'] = pd.DatetimeIndex(df['Date'])

    # Get all clippers games
    df = df[df['Visitor/Neutral'].str.contains(team1) | df['Home/Neutral'].str.contains(team1)]

    # Get all warriors games
    df = df[df['Visitor/Neutral'].str.contains(team2) | df['Home/Neutral'].str.contains(team2)]
    
    # Convert to string
    
    
    # Output List
    gamedates = df['Date'].tolist()
    
    
    # Convert to string
    new_gamedates = []
    for d in gamedates:
        new_date = str(d.month) + "-" + str(d.day) + "-" + str(d.year)
        new_gamedates.append(new_date)

    gamedates = new_gamedates
    
    return(gamedates)

# %%
# Grab data
def grabdataline(payload,newargs):
    """
    Grab one line of stats for a quarter
    """
    payload.update(newargs)
    baseurl = "http://stats.nba.com/stats/leaguedashteamstats"
    response=requests.get(baseurl,payload)
    print response.url
    print response
    # Grab headers
    headers = response.json()['resultSets'][0]['headers']

    # Grab stats

    stats = response.json()['resultSets'][0]['rowSet']

    periodframe = pd.DataFrame(stats,columns = headers )
    # Add arguments to data line
    for k,v in newargs.iteritems():
        periodframe[k] = v
    return(periodframe)

# %%
def response_to_frame(requestresponse):
    """Take a request response and convert to dataframe
    Only if headers and stats conform to sample nba protocol
    
    >>> df = response_to_frame(response)
    
    """
    # Grab column heads
    headers = response.json()['resultSets'][0]['headers']

    # Grab rows
    stats = response.json()['resultSets'][0]['rowSet']
    
    # Form frame
    df = pd.DataFrame(stats,columns = headers )
    
    # Return frame
    return(df)
